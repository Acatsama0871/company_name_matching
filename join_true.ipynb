# %%
import pandas as pd

# %%
remaining = pd.read_csv('data/06_merged_results/remaining.csv')
match_true = pd.read_csv('data/06_merged_results/match_true.csv')

# %%
remaining
# Out:
#                                      Target Name  Target No.  \
# 0                                1st Source Bank       22239
# 1                   21st Century Insurance Group       21615
# 2                    360 Capital Industrial Fund        3543
# 3                      AAG Holding Company, Inc.       20767
# 4            ABB Finance (Australia) Pty Limited        3541
# ..                                           ...         ...
# 583  Zijin International Capital Company Limited       10605
# 584  Zijin International Finance Company Limited        6661
# 585                    Zions First National Bank       21458
# 586                 Zoomlion HK SPV Co., Limited       10477
# 587                        Zur Rose Finance B.V.       16469
#
#                             preprocessed First word  \
# 0                        1st source bank        1st
# 1           21st century insurance group       21st
# 2            360 capital industrial fund        360
# ...

# %%
match_true
# Out:
#                               Target Name  Target No.   TRUE
# 0             360 Capital Industrial Fund        3543    NaN
# 1                   ABPA HOLDINGS LIMITED        9511    NaN
# 2                 AIG International, Inc.       21931    NaN
# 3                  ALD International S.A.        8556    NaN
# 4    AmBev International Finance Co. Ltd.        4155  AmBev
# ..                                    ...         ...    ...
# 583          CNOOC Finance (2003) Limited       25211  CNOOC
# 584          CNOOC Finance (2011) Limited       25231  CNOOC
# 585          CNOOC Finance (2012) Limited       25253  CNOOC
# 586          CNOOC Finance (2013) Limited       25290  CNOOC
# 587        CNOOC NEXEN FINANCE (2014) ULC        5294  CNOOC
#
# [588 rows x 3 columns]

# %%
remaining_with_true = pd.merge(remaining, match_true, on=['Target Name', 'Target No.'])
remaining_with_true
# Out:
#                                      Target Name  Target No.  \
# 0                                1st Source Bank       22239
# 1                   21st Century Insurance Group       21615
# 2                    360 Capital Industrial Fund        3543
# 3                      AAG Holding Company, Inc.       20767
# 4            ABB Finance (Australia) Pty Limited        3541
# ..                                           ...         ...
# 583  Zijin International Capital Company Limited       10605
# 584  Zijin International Finance Company Limited        6661
# 585                    Zions First National Bank       21458
# 586                 Zoomlion HK SPV Co., Limited       10477
# 587                        Zur Rose Finance B.V.       16469
#
#                             preprocessed First word  \
# 0                        1st source bank        1st
# 1           21st century insurance group       21st
# 2            360 capital industrial fund        360
# ...

# %%
remaining_with_true.to_csv('data/06_merged_results/remaining.csv', index=False)
